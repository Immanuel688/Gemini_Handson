# %%
from google import genai
from google.genai import types
import gradio as gr

client= genai.Client(api_key="")

system_message= "You are a financial expert specializing in real estate investment and negotiation"

def Customagent(user_input):
    response = client.models.generate_content(
    model="gemini-2.5-flash",
    config=types.GenerateContentConfig(
        system_instruction=system_message,
        max_output_tokens=1000
        ),
    contents=user_input
    )

    return response.text

# %%
# Gradio Interface
demo = gr.Interface(fn=Customagent, 
                    inputs="text", 
                    outputs="text", 
                    title="My Saving Assistant")

# Launch the app
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7865
# * Running on public URL: https://de4aa50c04070afeae.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://de4aa50c04070afeae.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# #https://googleapis.github.io/python-genai/#types
# #https://ai.google.dev/api/generate-content
