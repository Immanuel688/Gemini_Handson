# %%
import sys
print(sys.version)
# Out:
# 3.11.0 | packaged by Anaconda, Inc. | (main, Mar  1 2023, 18:18:21) [MSC v.1916 64 bit (AMD64)]

# %%
# !python --version
# Out:
# Python 3.11.0

# %%
#https://googleapis.github.io/python-genai/#types
#https://ai.google.dev/api/generate-content

# %%
pip install google-genai
# Out:
# ...
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# ...
#    ---------------------------------------- 0.0/703.4 kB ? eta -:--:--
#    ---------------------------------------- 703.4/703.4 kB 7.0 MB/s  0:00:00
# ...
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# ...
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# ...
#
#    ---------------------------------------- 0/7 [tenacity]
#    ----- ---------------------------------- 1/7 [pyasn1]
#    ----- ---------------------------------- 1/7 [pyasn1]
#    ----- ---------------------------------- 1/7 [pyasn1]
#    ----------- ---------------------------- 2/7 [cachetools]
#    ----------------- ---------------------- 3/7 [rsa]
#    ----------------- ---------------------- 3/7 [rsa]
#    ----------------- ---------------------- 3/7 [rsa]
# ...

# %%
pip show google-genai
# Out:
# Name: google-genai
# Version: 1.55.0
# Summary: GenAI Python SDK
# Home-page: https://github.com/googleapis/python-genai
# Author:
# Author-email: Google LLC <googleapis-packages@google.com>
# License-Expression: Apache-2.0
# Location: C:\anaconda3\envs\Chatgpt\Lib\site-packages
# Requires: anyio, distro, google-auth, httpx, pydantic, requests, sniffio, tenacity, typing-extensions, websockets
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from google import genai

client = genai.Client(api_key="AIzaSyA-5bDcG9neHJhgxqkLCG8fcQRbuYRY-_I")

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="How does AI work?"
)
print(response.text)
# Out:
# AI, or Artificial Intelligence, is a broad field of computer science that aims to create machines that can perform tasks traditionally requiring human intelligence. It's not magic, but rather a complex combination of data, algorithms, and computational power.
#
# Here's a breakdown of how AI generally works:
#
# ### 1. The Core Idea: Learning from Data
#
# At its heart, most modern AI (especially Machine Learning) doesn't just follow pre-programmed rules. Instead, it **learns patterns and makes decisions or predictions based on vast amounts of data.**
#
# Imagine you want to teach a child what a "cat" is. You don't give them a rigid set of rules ("it has fur, four legs, whiskers, meows..."). Instead, you show them many pictures of cats, point them out, and correct them when they make a mistake. AI learns in a similar (but more structured) way.
#
# ### 2. Key Components & Concepts
#
# ...

# %%
from google import genai

client = genai.Client(api_key="")
response = client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents="How does AI work?"
)
print(response.text)
# Out:
# The question of "how does AI work?" is a vast one, as "AI" is a broad umbrella term for many different technologies and approaches. However, at its core, AI aims to **mimic or simulate human intelligence in machines.** This is achieved through a combination of **data, algorithms, and computational power.**
#
# Here's a breakdown of the fundamental concepts:
#
# **1. Data is the Fuel:**
#
# * **Training Data:** AI systems, especially those relying on machine learning, learn from massive amounts of data. This data can be anything from images, text, numbers, audio, or even sensor readings.
# * **Patterns and Relationships:** The AI's goal is to identify patterns, correlations, and relationships within this data. For example, an image recognition AI might be trained on millions of images of cats and dogs, learning to associate specific visual features with each animal.
#
# **2. Algorithms are the Engine:**
#
# ...

# %% [markdown]
# # 2.0 flash and flash lite and 1.5 not working with both keys
# # 2.5 flash and flash lite is working with both keys
# # gemini-3-flash-preview working and gemini-3-pro-preview not working

# %%
from google import genai

client = genai.Client(api_key="")
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="what is quantum ai?"
)
print(response.text)
# Out:
# **Quantum AI** is the fusion of two of the most powerful technologies in the modern world: **Quantum Computing** and **Artificial Intelligence (AI).**
#
# At its core, it involves using quantum computers to run machine learning algorithms, allowing them to solve problems that are currently too complex or time-consuming for even the world’s fastest supercomputers.
#
# Here is a breakdown of how it works, why it matters, and what it could change.
#
# ---
#
# ### 1. The Foundation: How is it different?
# To understand Quantum AI, you have to look at the difference between "Classical" computing and "Quantum" computing.
#
# *   **Classical AI (Bits):** Standard computers use bits (0 or 1). When an AI processes data, it does so in a linear or parallel fashion, but it is limited by the fact that a bit can only be one thing at a time.
# ...

# %%
from google import genai

client = genai.Client(api_key="")
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="How does AI work?"
)
print(response.text)
# Out:
# At its simplest level, Artificial Intelligence (AI) is a field of computer science that builds systems capable of performing tasks that usually require human intelligence.
#
# While movies often portray AI as a "thinking brain," the reality is more about **math, data, and pattern recognition.** Here is a breakdown of how it works, from the ground up.
#
# ---
#
# ### 1. The Foundation: Data
# AI doesn’t have instincts or life experience; it has data. Data is the "fuel" for AI.
# *   To teach an AI to recognize a cat, you feed it millions of images of cats.
# *   To teach an AI to speak, you feed it billions of pages of human text.
# *   **The Goal:** The AI looks for recurring patterns in that data that a human might never notice.
#
# ### 2. The Logic: Algorithms and Machine Learning
# In traditional computing, a human writes a specific recipe: *"If X happens, do Y."*
#
# ...
