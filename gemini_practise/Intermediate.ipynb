# %%
from google import genai

client = genai.Client(api_key="")

# %%
system_message= input("what kind of assistant you would like to have?")
print(" Your assistant is ready !! ")
# Out:
# what kind of assistant you would like to have? financial advisor
#  Your assistant is ready !!

# %%
from google.genai import types

user_input= " shall i invest in silver ? "

response = client.models.generate_content(
    model="gemini-2.5-flash-lite",
    config=types.GenerateContentConfig(
        system_instruction=system_message),
    contents=user_input
)

print(response.text)
# Out:
# Investing in silver can be a complex decision, and whether it's the right move for you depends on a variety of factors, including your financial goals, risk tolerance, and overall investment strategy. There's no single "yes" or "no" answer that applies to everyone.
#
# Let's break down the pros and cons of investing in silver to help you make a more informed decision:
#
# **Potential Benefits of Investing in Silver:**
#
# *   **Store of Value and Inflation Hedge:** Like gold, silver is often seen as a safe-haven asset and a hedge against inflation. When the purchasing power of fiat currencies declines, the value of precious metals can potentially rise.
# *   **Industrial Demand:** Unlike gold, silver has significant industrial applications. It's used in electronics, solar panels, medical devices, and more. This dual nature (store of value + industrial utility) can create demand drivers beyond just investment.
# ...

# %%
system_message= input("what kind of assistant you would like to have?")
print(" Your assistant is ready !! ")

user_input= " shall i invest in silver ? "

response = client.models.generate_content(
    model="gemini-2.5-flash-lite",
    config=types.GenerateContentConfig(
        system_instruction=system_message,
        max_output_tokens=100,
        temperature=0),
    contents=user_input
)

print(response.text)
# Out:
# what kind of assistant you would like to have? Motivational assistant
#  Your assistant is ready !!
# Investing in silver can be a good idea for some people, but it's not a guaranteed win for everyone. Like any investment, it has its pros and cons.
#
# **Here's a breakdown to help you decide if silver is right for you:**
#
# **Potential Benefits of Investing in Silver:**
#
# *   **Hedge Against Inflation:** Silver, like gold, is often seen as a store of value. When the cost of goods and services rises (inflation), the value of precious metals

# %%
from google import genai
from google.genai import types

client= genai.Client(api_key="")

system_message= input("what kind of assistant you would like to have?")
print(" Your assistant is ready !! ")

while True:
    user_input= input()
    if user_input.lower() == "quit":
        break

    response = client.models.generate_content(
    model="gemini-3-flash-preview",
    config=types.GenerateContentConfig(
        system_instruction=system_message,
        max_output_tokens=100,
        temperature=0),
    contents=user_input
    )

     print(response.text)
# Out:
# what kind of assistant you would like to have? chef
#  Your assistant is ready !!
#  how to bake a cake
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[3], line 14
#      11     if user_input.lower() == "quit":
#      12         break
# ---> 14     response = client.models.generate_content(
#      15     model="gemini-3-flash-preview",
#      16     config=types.GenerateContentConfig(
#      17         system_instruction=system_message,
#      18         max_output_tokens=100,
#      19         temperature=0),
#      20     contents=user_input
#      21     )
#      23 print(response.text)
#
# File C:\anaconda3\envs\Chatgpt\Lib\site-packages\google\genai\models.py:5230, in Models.generate_content(self, model, contents, config)
#    5228 while remaining_remote_calls_afc > 0:
#    5229   i += 1
# -> 5230   response = self._generate_content(
# ...

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""Investing in silver can be a complex decision, and whether it's the right move for you depends on your individual financial goals, risk tolerance, and market outlook. There are potential benefits and drawbacks to consider.
#
# Here's a breakdown to help you think through it:
#
# **Potential Benefits of Investing in Silver:**
#
# *   **Hedge Against Inflation:** Like gold, silver is often seen as a store of value and can perform well during periods of high inflation when fiat currencies lose purchasing power"""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.MAX_TOKENS: 'MAX_TOKENS'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash-lite',
#   response_id='u6JGaYKYC4nXjuMP2qyC0A4',
#   sdk_http_response=HttpResponse(
# ...

# %%
from google import genai
from google.genai import types

client= genai.Client(api_key="")

system_message= input("what kind of assistant you would like to have?")
print(" Your assistant is ready !! ")

while True:
    user_input= input("Enter your query :" )
    if user_input.lower() == "quit":
        break

    response = client.models.generate_content(model="gemini-2.5-flash",
                                              config=types.GenerateContentConfig(system_instruction=system_message,
                                                                                 max_output_tokens=500,
                                                                                 temperature=0.7),
                                             contents=user_input)

    print(response.text)
# Out:
# what kind of assistant you would like to have? chef
#  Your assistant is ready !!
# Enter your query : ginger tea making
# Hello! As a chef, I appreciate ginger tea not just for its health benefits, but for its incredible balance of spicy, sweet
# Enter your query : quit

# %% [markdown]
# # the model's perform thinking internally which consumes tokens so increasing max output tokens fixed the response cut off

# %%
from google import genai
from google.genai import types
import time

client= genai.Client(api_key="")

system_message= input("what kind of assistant you would like to have?")
print(" Your assistant is ready !! ")

while True:
    user_input= input("Enter your query :" )
    if user_input.lower() == "quit":
        break
    response = client.models.generate_content(model="gemini-2.5-flash",
                                          config=types.GenerateContentConfig(system_instruction=system_message,
                                                                             max_output_tokens=3000,
                                                                             temperature=0.7),
                                          contents=user_input)

    print(response.text)
# Out:
# what kind of assistant you would like to have? chefbot
#  Your assistant is ready !!
# Enter your query : how to make a briyani?
# Biryani is a beloved, aromatic, and flavorful rice dish with origins in the Indian subcontinent. It's a complex dish but incredibly rewarding to make. There are many regional variations (Hyderabadi, Lucknowi, Kolkata, Malabar, etc.), but the core principle involves layering partially cooked rice with marinated meat (or vegetables) and slow-cooking it to perfection (dum cooking).
#
# Here's a classic **Hyderabadi Chicken Dum Biryani** recipe, which is one of the most popular and flavorful styles. This recipe requires a bit of time and effort, but the result is absolutely worth it!
#
# ---
#
# **Hyderabadi Chicken Dum Biryani**
#
# **Yields:** 6-8 servings
# **Prep time:** 45 minutes (plus 2-4 hours marination)
# **Cook time:** 1 hour 15 minutes
#
# **I. Ingredients:**
#
# **A. For the Chicken Marinade:**
# ...

# %%
print(f"Debug - Finish Reason: {response.candidates[0].finish_reason}")
# Out:
# Debug - Finish Reason: FinishReason.MAX_TOKENS

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text='Ginger tea is a wonderfully warming, soothing, and flavorful drink, perfect for any time of day,'
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.MAX_TOKENS: 'MAX_TOKENS'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   response_id='56ZXafbBE6uM4-EPxOOJoQc',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=20,
#     prompt_token_count=7,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=7
#       ),
#     ],
#     thoughts_token_count=476,
#     total_token_count=503
#   )
# )
